# %% [markdown]
# <a href="https://colab.research.google.com/github/LuganThierry/newworkx_notebooks/blob/main/networkscience_aula6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Erdös-Rényi

# %%
n = 25
p = 0.01
G = nx.erdos_renyi_graph(n, p)
nx.draw_networkx(G, pos=nx.circular_layout(G))

# %%
degree_list = [degree for node, degree in G.degree]
degree_list = pd.Series(degree_list)
degree_list.describe()
# Out:
# count    25.000000
# mean      0.160000
# std       0.374166
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000
# dtype: float64

# %%
n = 1000
p = 0.05
G = nx.erdos_renyi_graph(n, p, seed=42)
nx.draw_networkx(G, pos=nx.circular_layout(G))

# %%
nx.density(G)
# Out:
# 0.04964564564564564

# %%
nx.average_clustering(G)
# Out:
# 0.0498970261420734

# %%
nx.average_shortest_path_length(G)
# Out:
# 2.031027027027027

# %%
degree_list = [degree for node, degree in G.degree]
degree_list = pd.Series(degree_list)
degree_list.hist();

# %% [markdown]
# ## Barabási-Albert

# %%
n = 25
m = 2
G = nx.barabasi_albert_graph(n, m, seed=42)
nx.draw_networkx(G, pos=nx.circular_layout(G))

# %%
n = 1000
m = 20
G = nx.barabasi_albert_graph(n, m, seed=42)
print(G)
# Out:
# Graph with 1000 nodes and 19600 edges

# %%
nx.density(G)
# Out:
# 0.03923923923923924

# %%
nx.average_clustering(G)
# Out:
# 0.09419872194633475

# %%
nx.average_shortest_path_length(G)
# Out:
# 2.1682082082082084

# %%
degree_list = [degree for node, degree in G.degree]
degree_list = pd.Series(degree_list)
degree_list.hist();

# %%
y = degree_list.sort_values(ascending=False)
x = range(len(y))
plt.plot(x, y)
plt.loglog()
plt.xlabel('Posição (rank)')
plt.ylabel('Grau do nó');

# %% [markdown]
# ## Mundo pequeno

# %%
n = 25
k = 2
p = 0.9
G = nx.watts_strogatz_graph(n, k, p)
nx.draw_networkx(G, pos=nx.circular_layout(G))

# %%
n = 1000
k = 50
p = 0.15
G = nx.watts_strogatz_graph(n, k, p, seed=42)
print(G)
# Out:
# Graph with 1000 nodes and 25000 edges

# %%
nx.density(G)
# Out:
# 0.05005005005005005

# %%
nx.average_clustering(G)
# Out:
# 0.45582532018440797

# %%
nx.average_shortest_path_length(G)
# Out:
# 2.3744784784784785

# %%
degree_list = [degree for node, degree in G.degree]
degree_list = pd.Series(degree_list)
degree_list.hist();
